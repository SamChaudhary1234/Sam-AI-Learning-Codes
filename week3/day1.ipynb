# %% [markdown]
# # Week 3 — Day 1: Introducing Google Colab
#
# Week 3 shifts from frontier APIs to **open-source models** running on GPUs. Most labs run on Google Colab because it gives free or low-cost GPU access (T4 is enough for everything in this week).
#
# **Plan for the week:**
# - **Day 1** — Colab basics (this notebook)
# - **Day 2** — HuggingFace Pipelines (high-level inference API)
# - **Day 3** — Tokenizers across model families
# - **Day 4** — The Transformers library — Models, AutoModelForCausalLM, quantization, generation
# - **Day 5** — Capstone: Meeting Minutes generator (Whisper for transcription + Llama for summarization)
#
# If you don't already have a Google account, sign up at https://colab.research.google.com/. The free tier is enough for the projects in this week.
#
# > **Colab link:** *TODO — paste your own Colab notebook URL here once published.*
